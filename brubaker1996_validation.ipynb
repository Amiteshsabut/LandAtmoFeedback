# %% [markdown]
# # LandAtmoFeedback — Brubaker & Entekhabi (1996) validation
# This notebook runs the package verification and prints the published benchmark tables.

# %%
from landfeedback import full_validation_report
from landfeedback.benchmarks import brubaker1996
report = full_validation_report()
print(report.summary())
report.assert_valid()

# %%
brubaker1996.state_statistics()

# %%
brubaker1996.published_reporting_matrix()

# %%
report.paper_arithmetic

# %%
report.derivative_convergence
